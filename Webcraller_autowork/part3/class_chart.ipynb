# %%
import pandas as pd
from pandas_datareader import data
import yfinance as yfin
yfin.pdr_override()
df = data.get_data_yahoo('AAPL', start='2019-01-01', end='2020-01-01')
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2019-01-02  38.722500  39.712502  38.557499  39.480000  37.994488  148158800
# 2019-01-03  35.994999  36.430000  35.500000  35.547501  34.209961  365248800
# 2019-01-04  36.132500  37.137501  35.950001  37.064999  35.670364  234428400
# 2019-01-07  37.174999  37.207500  36.474998  36.982498  35.590961  219111200
# 2019-01-08  37.389999  37.955002  37.130001  37.687500  36.269440  164101200
# ...               ...        ...        ...        ...        ...        ...
# 2019-12-24  71.172501  71.222504  70.730003  71.067497  69.421066   48478800
# 2019-12-26  71.205002  72.495003  71.175003  72.477501  70.798393   93121200
# 2019-12-27  72.779999  73.492500  72.029999  72.449997  70.771538  146266000
# 2019-12-30  72.364998  73.172501  71.305000  72.879997  71.191566  144114400
# ...

# %%
df2 = data.get_data_yahoo('005930.KS', start="2019-01-01", end='2020-01-01')
df2
# Out:
# [*********************100%***********************]  1 of 1 completed
#                Open     High      Low    Close     Adj Close    Volume
# Date
# 2019-01-02  39400.0  39400.0  38550.0  38750.0  34283.785156   7847664
# 2019-01-03  38300.0  38550.0  37450.0  37600.0  33266.320312  12471493
# 2019-01-04  37450.0  37600.0  36850.0  37450.0  33133.609375  14108958
# 2019-01-07  38000.0  38900.0  37800.0  38750.0  34283.785156  12748997
# 2019-01-08  38000.0  39200.0  37950.0  38100.0  33708.695312  12756554
# ...             ...      ...      ...      ...           ...       ...
# 2019-12-23  56100.0  56400.0  55100.0  55500.0  50237.347656   9839252
# 2019-12-24  55600.0  55700.0  54800.0  55000.0  49784.753906  11868463
# 2019-12-26  54700.0  55400.0  54400.0  55400.0  50146.824219   9645034
# 2019-12-27  55700.0  56900.0  55500.0  56500.0  51471.417969  12313056
# 2019-12-30  56200.0  56600.0  55700.0  55800.0  50833.714844   8356767
#
# [246 rows x 6 columns]

# %%
df2['Close'] = df2['Close'].astype(float)
df2['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df['Close'].rolling(5).mean() # 5일치 평균
# Out:
# Date
# 2019-01-02        NaN
# 2019-01-03        NaN
# 2019-01-04        NaN
# 2019-01-07        NaN
# 2019-01-08    38130.0
#                ...
# 2019-12-24    55760.0
# 2019-12-26    55580.0
# 2019-12-27    55680.0
# 2019-12-30    55640.0
# 2019-12-31        NaN
# Name: Close, Length: 252, dtype: float64

# %%
df['Close'].rolling(5).sum() # 5일치 합계
# Out:
# Date
# 2019-01-02         NaN
# 2019-01-03         NaN
# 2019-01-04         NaN
# 2019-01-07         NaN
# 2019-01-08    190650.0
#                 ...
# 2019-12-24    278800.0
# 2019-12-26    277900.0
# 2019-12-27    278400.0
# 2019-12-30    278200.0
# 2019-12-31         NaN
# Name: Close, Length: 252, dtype: float64

# %%
df['rolling5'] = df['Close'].rolling(5).mean() # 5일치 평균
df
# Out:
#                  Open       High        Low    Close  Adj Close     Volume
# Date
# 2019-01-02  38.722500  39.712502  38.557499  38750.0  37.994488  148158800  \
# 2019-01-03  35.994999  36.430000  35.500000  37600.0  34.209961  365248800
# 2019-01-04  36.132500  37.137501  35.950001  37450.0  35.670364  234428400
# 2019-01-07  37.174999  37.207500  36.474998  38750.0  35.590961  219111200
# 2019-01-08  37.389999  37.955002  37.130001  38100.0  36.269440  164101200
# ...               ...        ...        ...      ...        ...        ...
# 2019-12-24  71.172501  71.222504  70.730003  55000.0  69.421066   48478800
# 2019-12-26  71.205002  72.495003  71.175003  55400.0  70.798393   93121200
# 2019-12-27  72.779999  73.492500  72.029999  56500.0  70.771538  146266000
# 2019-12-30  72.364998  73.172501  71.305000  55800.0  71.191566  144114400
# 2019-12-31  72.482498  73.419998  72.379997      NaN  71.711731  100805600
#
#             rolling5  rolling20
# Date
# ...

# %%
df['rolling20'] = df['Close'].rolling(20).mean() # 5일치 평균

# %%
df['rolling5'].plot()
df['Close'].plot()
df['rolling20'].plot()
# Out:
# <Axes: xlabel='Date'>
