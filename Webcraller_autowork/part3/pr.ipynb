# %%
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_table('./data/income.txt')
df
# Out:
#     age  income
# 0     1    67.0
# 1     1    62.0
# 2     2   109.0
# 3     2    83.0
# 4     2    91.0
# ..  ...     ...
# 75    4   160.0
# 76    5   125.0
# 77    4   160.0
# 78    3     NaN
# 79    4   170.0
#
# [80 rows x 2 columns]

# %%
df = df.dropna()

plt.scatter(df['age'], df['income'])
plt.show()

# %%
def fun(x, a, b, c):
    return a*x + b*x**2 + c

# %%
opt, cov = curve_fit(fun, df['age'], df['income'])
opt
# Out:
# array([73.24484048, -8.42672128, -7.00774851])

# %%
a, b, c = opt

# %%
import numpy as np

# %%
x = np.array(range(1, 7))
plt.scatter(df['age'], df['income'])
plt.plot(x, fun(x, a, b, c))
plt.show()

# %%
import statsmodels.api as st

x = np.column_stack([df['age'], df['age']**2, np.ones(79)])
model = st.OLS(df['income'], x).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 income   R-squared:                       0.793
# Model:                            OLS   Adj. R-squared:                  0.788
# Method:                 Least Squares   F-statistic:                     146.0
# Date:                Thu, 27 Jul 2023   Prob (F-statistic):           9.30e-27
# Time:                        11:15:53   Log-Likelihood:                -298.90
# No. Observations:                  79   AIC:                             603.8
# Df Residuals:                      76   BIC:                             610.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            73.2448      5.195     14.100      0.000      62.899      83.591
# x2            -8.4267      0.731    -11.531      0.000      -9.882      -6.971
# const         -7.0077      9.126     -0.768      0.445     -25.184      11.169
# ==============================================================================
# Omnibus:                        3.037   Durbin-Watson:                   1.201
# Prob(Omnibus):                  0.219   Jarque-Bera (JB):                2.100
# Skew:                          -0.210   Prob(JB):                        0.350
# Kurtosis:                       2.321   Cond. No.                         142.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
